# %% [markdown]
# <a href="https://colab.research.google.com/github/aztofighi/LLM-Essay-Creator/blob/main/Create_Essay_LLM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install faker --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 12.8 MB/s eta 0:00:00

# %%
import torch
DEVICE = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
print(f"Device: {DEVICE}")
print(f"CUDA Version: {torch.version.cuda}")
print(f"Pytorch {torch.__version__}")
# Out:
# Device: cpu
# CUDA Version: 12.1
# Pytorch 2.2.1+cu121

# %%
import sys, random, string, re, time, os
import pandas as pd
import numpy as np
from transformers import BitsAndBytesConfig, AutoModelForCausalLM, AutoTokenizer, pipeline
from tqdm.auto import tqdm
from faker import Faker  #generates fake data
from spacy.lang.en import English

# %%
import torch, random
# Ensure that all operations are deterministic on GPU (if used) for reproducibility
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

SEED = 42
# Seed the same seed to all
def seed_everything(seed=42):
    Faker.seed(0)
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)

seed_everything(SEED)

# %%
import ctypes, gc, torch
libc = ctypes.CDLL("libc.so.6")
def clear_memory():
    libc.malloc_trim(0)
    torch.cuda.empty_cache()
    gc.collect()

# %% [markdown]
# Generate Fake Student Information
# Generate student information (first name, last name, address, email, etc.) using the Faker and random libraries. Save the generated data to a CSV file for later loading

# %%
# Random generate 12 random number
def get_userid(length=16):
    """Generate userid - """
    userid = str(int(np.random.rand()*1_000_000_000))
    # Add the extra rand chars
    for i in range(length):
        # Select random char or digital number (0-9)
        userid = userid + random.choice(string.ascii_letters + str(random.randint(0, 9)))
    return userid

# Generate the personal url from social media
def generate_fake_social_media_url(user_name):
    social_media_platforms = {
        'LinkedIn': 'linkedin.com/in/',
        'YouTube': 'youtube.com/c/',
        'Instagram': 'instagram.com/',
        'GitHub': 'github.com/',
        'Facebook': 'facebook.com/',
        'Twitter': 'twitter.com/'
    }
    platform, domain = random.choice(list(social_media_platforms.items()))
    fake_url = f'https://{domain}{user_name}'
    return fake_url

def generate_username(first_name, last_name, fake_user_name):
    """usernames are created from first_name and last_name"""
    SEPS = ["_", ".", ""]
    if random.choice([False, True]):
        username = f"{first_name.lower()}{random.choice(SEPS)}{last_name.lower()}{random.randint(1,999)}"
    else:
        username = fake_user_name
    return username

def generate_email(first_name, last_name, faker):
    """usernames are created from first_name and last_name"""
    SEPS = ["_", ".", ""]
    if random.choice([False, True]):
        email = f"{first_name.lower()}{random.choice(SEPS)}{last_name.lower()}@{faker.domain_name()}"
    else:
        email = faker.email()
    return email

def generate_student_info():
    """Generates all the user info (name, eamil addresses, phone number, etc) together """
    # Select the student country to generate the user info based on the country
    COUNTRIES = ["en_US", "en_US", "en_US", "en_US", "en_US", "en_US",
                 "de_DE", "it_IT", "es_ES", "da_DK", "fr_FR", "vi_VN"]
    country = random.choice(COUNTRIES)
    faker = Faker(country)
    first_name = faker.first_name()
    last_name = faker.last_name()
    user_name = generate_username(first_name, last_name, faker.user_name())
    fake_url = generate_fake_social_media_url(user_name)
    student = {}
    student['COUNTRY'] = country
    student['ID_NUM'] = get_userid() # User ID
    student['NAME_STUDENT'] = first_name + " "+  last_name
    student['EMAIL'] = generate_email(first_name, last_name, faker)
    student['USERNAME'] = user_name
    student['PHONE_NUM'] = faker.phone_number().replace(" ", "")
    student['URL_PERSONAL'] = fake_url
    student['STREET_ADDRESS'] = str(faker.address()).replace("\n"," ") # Replace \n with space in the address
    del faker
    clear_memory()
#     print(student)
    return student

# %%
from pathlib import Path
# Copy the generated df to working folder
import shutil

GENERATED = True
# Create the folder
Path("/content").mkdir(parents=True, exist_ok=True)
if GENERATED:
    TOTAL = 100 # Generate 100
    students = []
    for i in tqdm(range(TOTAL)):
        students.append(generate_student_info())
        print(f"Generate {i}-th information")
    df = pd.DataFrame(students)
    df = df.reset_index(drop=True)
    # Save to the csv file
    df.to_csv("/content/df.csv", index=False, encoding='UTF-8') # Do not save default ID column
    display(df.tail(10))
    # Check if ID_NUM has any duplicates
    assert df['ID_NUM'].duplicated().value_counts()[False] == TOTAL, "Duplicated ID_NUM"
else:
    shutil.copy('/kaggle/input/ai-generated-text-dataset/temp/df.csv', '/kaggle/working/temp/df.csv')
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# Generate 0-th information
# Generate 1-th information
# Generate 2-th information
# Generate 3-th information
# Generate 4-th information
# Generate 5-th information
# Generate 6-th information
# Generate 7-th information
# Generate 8-th information
# Generate 9-th information
# Generate 10-th information
# Generate 11-th information
# Generate 12-th information
# Generate 13-th information
# Generate 14-th information
# Generate 15-th information
# Generate 16-th information
# Generate 17-th information
# Generate 18-th information
# Generate 19-th information
# Generate 20-th information
# Generate 21-th information
# Generate 22-th information
# Generate 23-th information
# Generate 24-th information
# Generate 25-th information
# Generate 26-th information
# Generate 27-th information
# Generate 28-th information
# Generate 29-th information
# Generate 30-th information
# Generate 31-th information
# Generate 32-th information
# Generate 33-th information
# Generate 34-th information
# Generate 35-th information
# Generate 36-th information
# Generate 37-th information
# Generate 38-th information
# Generate 39-th information
# Generate 40-th information
# Generate 41-th information
# Generate 42-th information
# Generate 43-th information
# Generate 44-th information
# Generate 45-th information
# Generate 46-th information
# Generate 47-th information
# Generate 48-th information
# Generate 49-th information
# Generate 50-th information
# Generate 51-th information
# Generate 52-th information
# Generate 53-th information
# Generate 54-th information
# Generate 55-th information
# Generate 56-th information
# Generate 57-th information
# Generate 58-th information
# Generate 59-th information
# Generate 60-th information
# Generate 61-th information
# Generate 62-th information
# Generate 63-th information
# Generate 64-th information
# Generate 65-th information
# Generate 66-th information
# Generate 67-th information
# Generate 68-th information
# Generate 69-th information
# Generate 70-th information
# Generate 71-th information
# Generate 72-th information
# Generate 73-th information
# Generate 74-th information
# Generate 75-th information
# Generate 76-th information
# Generate 77-th information
# Generate 78-th information
# Generate 79-th information
# Generate 80-th information
# Generate 81-th information
# Generate 82-th information
# Generate 83-th information
# Generate 84-th information
# Generate 85-th information
# Generate 86-th information
# Generate 87-th information
# Generate 88-th information
# Generate 89-th information
# Generate 90-th information
# Generate 91-th information
# Generate 92-th information
# Generate 93-th information
# Generate 94-th information
# Generate 95-th information
# Generate 96-th information
# Generate 97-th information
# Generate 98-th information
# Generate 99-th information
#    COUNTRY                     ID_NUM       NAME_STUDENT  \
# 90   en_US  119594245AiylOSJFiuNwFmJP        Melvin Rowe
# 91   fr_FR  713244787kKYsrIkKJhhX8IWI  Christiane Wagner
# 92   de_DE  760785048tCwCXnSTOki3ZKIM   Gundula Losekann
# 93   en_US  561277197RidPSpTpFKOyezVS      Deborah White
# 94   it_IT  770967179UOezBFuvKKYRcObk   Lando Mascheroni
# 95   en_US  493795596kfqxdOUBTaEioRaS    Courtney Mullen
# 96   de_DE  522732829ofgxiXPeKNCUOARn      Margot Etzold
# 97   en_US  427541018UwupPpMUsQnMmsYF  Samantha Williams
# 98   en_US   25419126auyAIWXbeqcYGOXB       Dawn Mullins
# 99   fr_FR  107891426tGZIzOtUdfhNdQhT   Philippe Schmitt
#
#                                 EMAIL              USERNAME  \
# 90         melvin.rowe@day-watson.org     natashamccullough
# 91            veronique67@example.net  christiane.wagner728
# 92               walter85@example.com                xtrueb
# 93  deborah.white@sanders-collins.net      deborah.white587
# 94     lando.mascheroni@battaglia.com      landomascheroni3
# 95      courtney_mullen@kemp-rice.com    courtney_mullen706
# 96            margareta53@example.net           gerlachsina
# 97        samantha_williams@ayala.com            jennifer56
# 98     dawn_mullins@watkins-nixon.com        dawnmullins609
# 99                ilebrun@example.net              hboucher
#
#                PHONE_NUM                              URL_PERSONAL  \
# 90  001-443-201-7823x695    https://facebook.com/natashamccullough
# 91            0183015666   https://github.com/christiane.wagner728
# 92            0925067741                https://twitter.com/xtrueb
# 93            6278211744    https://instagram.com/deborah.white587
# 94          +39012582111      https://twitter.com/landomascheroni3
# 95       +1-898-764-3912  https://youtube.com/c/courtney_mullen706
# 96      +49(0)8724531935            https://github.com/gerlachsina
# 97  +1-824-658-1273x9991        https://linkedin.com/in/jennifer56
# 98     (910)865-2736x903    https://linkedin.com/in/dawnmullins609
# 99            0767149544            https://instagram.com/hboucher
#
#                                        STREET_ADDRESS
# 90  5039 Carlos Curve Apt. 886 Jaredchester, AK 71876
# 91                96, avenue Bousquet 36789 Brunetnec
# 92                  Pierre-Barth-Weg 2 71129 Geithain
# 93  7104 Sarah Motorway Suite 836 South Billyland,...
# 94  Strada Carosone, 7 Appartamento 95 34076, Mede...
# 95  500 Douglas Streets Apt. 221 Navarroberg, KY 3...
# 96                      Wohlgemutstraße 0 36068 Ebern
# 97               0092 Jackson Lodge New Amy, ID 04639
# 98  66734 Jacqueline Estate West Rhondaburgh, CT 2...
# 99             880, boulevard de Gaudin 25532 Foucher

# %% [markdown]
# Generate texts using LLM¶
# Load Models
# Using LLM Mistral-7b-instruct-v0.1-hf to generate the essays with given PII information (like name, email, etc).

# %%
def load_model():
    torch.backends.cuda.enable_mem_efficient_sdp(False)
    torch.backends.cuda.enable_flash_sdp(False)
    model_path="/kaggle/input/mistral/pytorch/7b-instruct-v0.1-hf/1"
    tokenizer = AutoTokenizer.from_pretrained(model_path, use_fast=True)

    model = AutoModelForCausalLM.from_pretrained(model_path,
                                                 torch_dtype=torch.bfloat16,
                                                 device_map="auto")
    return model, tokenizer

# %% [markdown]
# Generate loop¶
# The loop generate the texts based on each student's PII information, including name + email + street address + phone + username + user id + personal url.
#
# All the generated texts are stored to generate_df.csv

# %%
def generate_on_user_info(row):
    # Prompt template generates the texts
    prompt_template = """<s>[INST]
    You are an essay writer.
    You will be given some personal information about the student writing it, like
    name = {first_name} {last_name}
    email = {email}
    street address = {address}
    phone number = {phone_num}
    personal url = {url}
    username = {username}
    user id = {userid}
    You need to write a short essay that includes all the given information somewhere in the essay.
    Do not miss out any.[/INST]"""

    first_name = row['NAME_STUDENT'].split()[0]
    last_name = row['NAME_STUDENT'].split()[1]
    email = row['EMAIL']
    phone_num = row['PHONE_NUM']
    address = row['STREET_ADDRESS']
    url = row['URL_PERSONAL']
    username = row['USERNAME']
    userid = row['ID_NUM']
    # Fill in prompt with PII
    prompt = prompt_template.format(first_name=first_name,
                                    last_name=last_name,
                                    email=email,
                                    phone_num=phone_num,
                                    address=address,
                                    url=url,
                                    username=username,
                                    userid=userid
                                   )
    return prompt

def generate_texts(model, tokenizer, df, num_essays):
    generated_df = df[:num_essays]
    # Generate the texts
    for i in tqdm(range(len(generated_df))):
        start = time.time()
        # Generate PII
        row = generated_df.loc[i]
        # Generate the texts using three prompts
        prompt = generate_on_user_info(row)
        # Tokenize the prompt
        inputs = tokenizer(prompt, return_tensors="pt").to(DEVICE)

        # Generate the outputs from prompt
        generate_ids = model.generate(**inputs,
                                      max_new_tokens=768,
                                      do_sample=True,
                                      temperature=0.7,
                                      top_p=0.95,
                                      top_k=40,
                                      repetition_penalty=1.1,
                                      pad_token_id=tokenizer.eos_token_id
                                     )
        # Decode the generated output
        generated_text = tokenizer.batch_decode(generate_ids, skip_special_tokens=True,
                                                 clean_up_tokenization_spaces=False)[0]
        generated_text = generated_text.split('[/INST] ')[1]
#         print(f"generated_text = {generated_text}" )
        generated_df.loc[i, 'generated_text'] = generated_text
        clear_memory()
        print(f"Complete the text for {i}-th student {time.time() - start: .1f} seconds")
    # Save generated_df to csv
    generated_df.to_csv("temp/generated_df.csv", index=False, encoding="UTF-8")

# %%
GENERATED = False  # True: Generate texts
if GENERATED:
    model, tokenizer = load_model()
    generate_texts(model, tokenizer, df, num_essays=20)
    sys.exit(0)

# %% [markdown]
# Turn Generated Texts to competition format

# %%
# Load the generated df from Gemma
df = pd.read_csv('/content/sample_data/Essay Creator/generated_df_0_100.csv', encoding='UTF-8')
df2 = pd.read_csv('/content/sample_data/Essay Creator/generated_df_100_900.csv', encoding='UTF-8')
df3 = pd.read_csv('/content/sample_data/Essay Creator/generated_df_900_1700.csv', encoding='UTF-8')
generated_df = pd.concat([df, df2, df3])
generated_df = generated_df.reset_index(drop=True, inplace=False)
generated_df = generated_df.rename({'generated_text': 'Essay'}, axis=1)
# Load the generated df from Gemini
df4 = pd.read_csv('/content/sample_data/Essay Creator/pii_gemini.csv',
                  encoding='UTF-8', index_col=[0]) # Load df without unnamed columns
df4['NAME_STUDENT'] = ['' for _ in range(len(df4))] # The dataset lacks of student name
df4 = df4.reset_index(drop=True, inplace=False)
# Combine both datasets
generated_df = pd.concat([generated_df, df4])
# generated_df = df4
generated_df = generated_df.reset_index(drop=True, inplace=False)
display(generated_df.tail(1))
# Out:
#      COUNTRY         ID_NUM NAME_STUDENT                  EMAIL USERNAME  \
# 5478     NaN  ['001884899']               ['rherman@gmail.com']       []
#
#                      PHONE_NUM                           URL_PERSONAL  \
# 5478  ['+1-810-639-5189x9133']  ['https://linkedin.com/in/william10']
#
#      STREET_ADDRESS                                              Essay
# 5478             []  In the tapestry of life, personal experiences ...

# %%
label_types = ['NAME_STUDENT','EMAIL', 'USERNAME', 'ID_NUM',
               'PHONE_NUM', 'URL_PERSONAL', 'STREET_ADDRESS']

# %% [markdown]
# Label assignment functions

# %%
from spacy.lang.en import English
import re

en_tokenizer = English().tokenizer

def tokenize_with_spacy(text, tokenizer=en_tokenizer):
    tokenized_text = tokenizer(text)
    tokens = [token.text for token in tokenized_text]
    trailing_whitespace = [bool(token.whitespace_) for token in tokenized_text]
    return tokens, trailing_whitespace

# Update labels and boolean flags
def update_labels(i, token, label_type, labels, isFirst_flags):
#     print(f"Found {i}-th position token: {token}")
    # Update the label
    if isFirst_flags[label_type]:
        labels[i] = 'B-'+label_type # Beginning of an entity
        isFirst_flags[label_type] = False
    else:
        labels[i] = 'I-'+label_type # Contiunity of an entity
    return labels, isFirst_flags

# Go through each token and assign name label ('NAME_STUDENT') if matched
def assign_name(names, tokens, labels):
    #print(f"Search 'NAME_STUDENT': {names}")
    for i, token in enumerate(tokens):
        token = str(token).lower()
        # Order does not matter
        if token in names:
            # If the previous
            if i > 0 and labels[i-1] == 'B-NAME_STUDENT':
                labels[i] = 'I-NAME_STUDENT'
            else:
                labels[i] = 'B-NAME_STUDENT'
    return labels

def assign_phone_number(phones, tokens, labels, isFirst_flags):
#     print(f"Search 'PHONE_NUM': {phone_tokens}")
    for i, token in enumerate(tokens):
        token_ = str(token).lower()
        label = labels[i]
        # Add a special case '-'
        if token == '-':
            # Check if the previous token is not 'O'
            if labels[i-1] != 'O':
                # Update the labels
                labels, isFirst_flags = update_labels(i, token_, 'PHONE_NUM',
                                                      labels, isFirst_flags)
        else:
            # Check if token is matched last name
            if label == 'O' and token_ in phones:
                labels, isFirst_flags = update_labels(i, token_, 'PHONE_NUM',
                                                      labels, isFirst_flags)
    return labels, isFirst_flags

# Go through each token and assign street address label
def assign_street_address(address, tokens, labels):
    # print(tokens)
    # Keep track of index for a long label
    label_index = 0
    reserve_indices = []
    sandwich_max_size = 3
    #print(f'address = {address}')
    for i, token in enumerate(tokens):
        try:
            #Order matters and sandwiches are possible
            token = str(token).lower()
            curr_idx = label_index
            curr_token = address[curr_idx]
            if token == curr_token:
                # print(f"token = {token}")
                #case where a token corresponds to the expected next token
                if len(reserve_indices) > sandwich_max_size:
                    reserve_indices = []

                prefix = 'B-' if curr_idx == 0 else 'I-'
                labels[i] = prefix + 'STREET_ADDRESS'
                #fill sandwiches if the next token has been found
                for k in reserve_indices:
                    labels[k] = 'I-STREET_ADDRESS'
                reserve_indices = []
                #Update positional pointer
                label_index += 1
                # At the end of address
                if label_index == len(address):
                    label_index = 0
                # print(f'label_index = {label_index}')
            else:
                reserve_indices.append(i)
                #print(f"! {token}")
        except Exception as e:
            print(f"Error occurs at {i}-th {token} \n{e}" )
            sys.exit(-1)
#         #case where some surprise token has been added in the PII
#     address_labels = [(label, token) for i, (label, token) in enumerate(zip(labels, tokens))
#                       if label =='B-STREET_ADDRESS' or label == 'I-STREET_ADDRESS']
#     print(address_labels)

    return labels

# Assign labels for other types
def assign_other_label_types(essay, label_type, tokens, labels, isFirst_flags):
    label_value = essay[label_type].lower()
#     print(f"Search '{label_type}': {label_value}")
    for i, token in enumerate(tokens):
        token_ = str(token).lower()
        # Check if token is first or last name
        if label_value in token_:
            # Update the label
            labels, isFirst_flags = update_labels(i, token_, label_type,
                                                      labels, isFirst_flags)
    return labels, isFirst_flags

# Assign labels for other types
def assign_email(email, tokens, labels):
    #print(f"Search Email: {email}")
    is_First = False
    for i, token in enumerate(tokens):
        token_ = str(token).lower()
        # Check if token is first or last name
        if email in token_:
            # print(f'Token {token_}')
            if not is_First:
                # Update the label
                labels[i] = 'B-EMAIL'
                is_First = True
            else: # Skip labeling
                print(f"Duplicated Email {email}")
    return labels

# Assign labels for other types
def assign_username(username, tokens, labels):
    #print(f"Search username: {username}")
    is_First = False
    for i, token in enumerate(tokens):
        token_ = str(token).lower()
        # Check if token is first or last name
        if username in token_:
            # print(f'Token {token_}')
            if not is_First:
                # Update the label
                labels[i] = 'B-USERNAME'
                is_First = True
            else: # Skip labeling
                print(f"Duplicated username {username}")
    return labels

# %% [markdown]
# Assign labels

# %%
# “B-”: the beginning of an entity.
# “I-”: the next of an entity
def assign_labels(essay, tokens):
    # print(f"essay['NAME_STUDENT'] = {essay['NAME_STUDENT']}" )
    # Assign "O" to labels by default
    labels = ['O' for token in tokens]
    # Create a boolean flag list to track if a label type start the text.
    isFirst_flags = {label_type: True for label_type in label_types}
    # Go through each token and check if the label appear in the token
    # All token and label values are lower case for comparison
    for label_type in label_types:
        if label_type == 'NAME_STUDENT':
            if essay['NAME_STUDENT'] != '':
                names, _ = tokenize_with_spacy(essay['NAME_STUDENT'].lower())
                labels = assign_name(names, tokens, labels)
        elif label_type == 'STREET_ADDRESS':
            address = essay['STREET_ADDRESS'].lower().replace("\\n", " ")
            # print(f"address {address}")
            address = address.translate(str.maketrans('', '', string.punctuation)) # Remove punctuations
            address = address.split(' ')
            if len(address) > 0:
                labels = assign_street_address(address, tokens, labels)
        elif label_type == 'PHONE_NUM':
            phones, _ = tokenize_with_spacy(essay['PHONE_NUM'].lower())
            labels, isFirst_flags = assign_phone_number(phones, tokens, labels, isFirst_flags)
        elif label_type == 'EMAIL':
            email = essay['EMAIL'].lower()
            assign_email(email, tokens, labels)
        elif label_type == 'USERNAME':
            username = essay['USERNAME'].lower()
            assign_username(username, tokens, labels)
        else:
            labels, isFirst_flags = assign_other_label_types(essay, label_type, tokens,
                                                             labels, isFirst_flags)
    return labels

# %%
def process_full_text(full_text):
    if 'Unprocessed:' in full_text: # Need to split the instruction and response
        pattern = r'([*]*Please write an essay about [^*]*[*]*)'
        x = re.search(pattern, full_text)
        if x:
            splits = re.split(pattern, full_text)
            text = splits[-1].strip()
            # print(f"=== Split text ===\n {text}")
            return text
        else:
            print(f"### UnProcess text###\n {full_text}")
            return None
    else:
        return full_text.strip() # Remove the space to the left

# Map the label to token
def create_token_map(tokens, labels):
    token_map = []
    for i, label in enumerate(labels):
        if label != 'O':
            token_map.append({label: (tokens[i], i)})
    return token_map

# %%
# Assign the labels to the tokens
results = []
doc_id = 1_221_555_000 # document id
for i in range(len(generated_df)):
    row = generated_df.iloc[i]
    full_text = process_full_text(row["Essay"])
    if full_text:
        # Tokenize the text using spacy tokenizer
        tokens, trailing_whitespace = tokenize_with_spacy(full_text)
        labels = assign_labels(row, tokens)
        token_map = create_token_map(tokens, labels)
        doc_id += 1
        result = {
            'document': doc_id,
            'full_text': full_text,
            'tokens': tokens,
            'trailing_whitespace': trailing_whitespace,
            'labels': labels,
            'token_map': token_map
        }
        # Add PII to result
        for label_type in label_types:
            result[label_type] = row[label_type]
        # print(result)
        results.append(result)
# # Save to temp fold for verification
df = pd.DataFrame(results)
df.to_csv("/content/sample_data/Essay Creator/pii_dataset_Gemma1.csv", index=False, encoding="UTF-8")
display(df)
# Out:
# Duplicated username michael_stewart95
# Duplicated username tverdugo
# Duplicated username franklinjames
# Duplicated username franklinjames
# Duplicated username danielleshea
# Duplicated username michelle71
# Duplicated username johnblair
# Duplicated username hugowerner696
# Duplicated username fdavis
# Duplicated username justintaylor828
# Duplicated username derek_weeks896
# Duplicated username michellechevalier
# Duplicated username francis.mullins694
# Duplicated username lligorio
# Duplicated username lligorio
# Duplicated username luc_ledoux408
# Duplicated username mario.papetti748
# Duplicated username caleb.davis107
# Duplicated username melaniacoronado
# Duplicated username rico_gomila407
# Duplicated username ronaldoborroni311
# Duplicated username william_gibson520
# Duplicated username antonia_adolph651
# Duplicated username ymontenegro
# Duplicated username jason_clayton779
# Duplicated username sharon_haynes965
# Duplicated username philipriley242
# Duplicated username nicolas_diallo183
# Duplicated username zabba
# Duplicated username zabba
# Duplicated username parkerallen327
# Duplicated username jimmywilliams904
# Duplicated username joseph.mccann387
# Duplicated username carolyn_wang739
# Duplicated username patriziochiappetta519
# Duplicated username natashamccullough
# Duplicated username natashamccullough
# Duplicated username jennifer56
# Duplicated username murciacristian
# Duplicated username dantrupp
# Duplicated username dantrupp
# Duplicated username dantrupp
# Duplicated username patriciathompson714
# Duplicated username kathyrodriguez
# Duplicated username nathaliepascal
# Duplicated Email tristanbernier@example.com
# Duplicated username denis_labbé380
# Duplicated username denis_labbé380
# Duplicated username denis_labbé380
# Duplicated username woodbrian
# Duplicated username shelly.schroeder986
# Duplicated username sophiamoore
# Duplicated username taylor72
# Duplicated username ortruntrüb938
# Duplicated username dietlinderose271
# Duplicated username dietlinderose271
# Duplicated username dawn62
# Duplicated username paulina_ravn118
# Duplicated username john86
# Duplicated username vravaglioli
# Duplicated username thomas.hofmann602
# Duplicated username adammay833
# Duplicated username hjalte.christiansen920
# Duplicated Email jaimeclark@williams.com
# Duplicated username jaime_clark360
# Duplicated username jaime_clark360
# Duplicated username jaime_clark360
# Duplicated username todd.smith235
# Duplicated username todd.smith235
# Duplicated username nicole.adams375
# Duplicated username cynthia_jones733
# Duplicated username cynthia_jones733
# Duplicated username sampsonthomas
# Duplicated username chelseawillis190
# Duplicated username federica37
# Duplicated username nathan.morgan925
# Duplicated username smithsharon
# Duplicated username benoît.blanc771
# Duplicated username zchandler
# Duplicated username marydaniel135
# Duplicated username lcollins
# Duplicated username lcollins
# Duplicated username erikapineda
# Duplicated username patriciawilliams
# Duplicated username mark.fields68
# Duplicated username gboyer
# Duplicated username gboyer
# Duplicated username barry_henson592
# Duplicated username jessicaduarte455
# Duplicated username carrie.moyer605
# Duplicated username vgonzalez
# Duplicated username michael_baker631
# Duplicated username leif66
# Duplicated username götz.hertrampf62
# Duplicated username autumn.rivas156
# Duplicated username anthony21
# Duplicated username peter.johnson429
# Duplicated username adamsthomas
# Duplicated username gabriella66
# Duplicated username gabriella66
# Duplicated username edwardsjeffrey
# Duplicated username carinadahl
# Duplicated username brian.lynch900
# Duplicated username reynoldswilliam
# Duplicated Email xallen@example.net
# Duplicated username lawsonrobert
# Duplicated username fprince
# Duplicated username fprince
# Duplicated username pguillaume
# Duplicated username jon.glover735
# Duplicated username nathaniel96
# Duplicated username loretta_häring246
# Duplicated username erhardtsölzer191
# Duplicated username erhardtsölzer191
# Duplicated username erhardtsölzer191
# Duplicated username ethan40
# Duplicated username grégoire.baron412
# Duplicated username blee
# Duplicated username blee
# Duplicated username michaelharmon464
# Duplicated username davidbonilla
# Duplicated username lditschlerin
# Duplicated username xsmith
# Duplicated username clarkjill
# Duplicated username farleymark
# Duplicated username lillidehmel
# Duplicated username raymundlange771
# Duplicated username bmorin
# Duplicated username remyrobin
# Duplicated username madlen.fiebig776
# Duplicated username davisashlee
# Duplicated username margittaniemeier669
# Duplicated username brivera
# Duplicated username kendra55
# Duplicated username kendra55
# Duplicated username valerio.antonini515
# Duplicated username wendy.johnson203
# Duplicated username stephanie_petty632
# Duplicated username joesnyder
# Duplicated username wmontgomery
# Duplicated username wmontgomery
# Duplicated username kelli33
# Duplicated username nguillon
# Duplicated username nguillon
# Duplicated username victor_kristiansen50
# Duplicated username alain_legros907
# Duplicated username brittany.cummings383
# Duplicated username laura_garcia477
# Duplicated username christinajacobs628
# Duplicated username veronique63
# Duplicated username laura.lloyd401
# Duplicated username laura.lloyd401
# Duplicated username contrerasbetty
# Duplicated username jenniferking321
# Duplicated username ruggero_garobbio87
# Duplicated username silvia96
# Duplicated username silvia96
# Duplicated username cbarbier
# Duplicated username george_koch661
# Duplicated username odette.pinto986
# Duplicated username mille.nielsen669
# Duplicated username adrienne_blin555
# Duplicated username ashleymiles
# Duplicated username guillaume43
# Duplicated username guillaume43
# Duplicated username darrellsanchez
# Duplicated username leonard52
# Duplicated username zhunter
# Duplicated username zhunter
# Duplicated username zhunter
# Duplicated username jesusa_murillo671
# Duplicated username jesusa_murillo671
# Duplicated username weberkyle
# Duplicated username eustaquio_aroca526
# Duplicated username ginesenapoleone
# Duplicated username ginesenapoleone
# Duplicated username ginacooper778
# Duplicated username debbie40
# Duplicated username simonlarsen384
# Duplicated username carrie_gordon213
# Duplicated username helen_jacobsen258
# Duplicated username lisariley610
# Duplicated username steven.frazier334
# Duplicated username mateo.aroca946
# Duplicated username concetta37
# Duplicated username brendadaniel663
# Duplicated username kenneth69
# Duplicated username carlos_hampton891
# Duplicated username carlos_hampton891
# Duplicated username jonathankoch532
# Duplicated username dsobrero
# Duplicated username dawnbrown366
# Duplicated username timothy_lynch732
# Duplicated username patrick.paris933
# Duplicated username patrick.paris933
# Duplicated username richard_roux965
# Duplicated username richard_roux965
# Duplicated username boydjohn
# Duplicated username stella39
# Duplicated username elvira_toninelli241
# Duplicated username kevinsutton240
# Duplicated username sarahmason
# Duplicated username oroger
# Duplicated username danieljohnston960
# Duplicated username emily_smith213
# Duplicated username rolando_lippomano709
# Duplicated username browndavid
# Duplicated username michael_holmes176
# Duplicated username ferdi76
# Duplicated username virginia.lucero491
# Duplicated username calvin.colon542
# Duplicated username bodil.bach979
# Duplicated username mariana.surian603
# Duplicated username ukambs
# Duplicated username taylor_patton514
# Duplicated username lindagarner766
# Duplicated username kaitlin03
# Duplicated username karengriffith
# Duplicated username william39
# Duplicated username william39
# Duplicated username palle_kristensen433
# Duplicated username jessica49
# Duplicated username roberto_lam107
# Duplicated username rvega
# Duplicated username ruppersbergerhermine
# Duplicated username fgierschner
# Duplicated username fgierschner
# Duplicated username carla58
# Duplicated username kristimills810
# Duplicated username stephaneparis
# Duplicated username zentajähn889
# Duplicated username marvindawson591
# Duplicated username rené_hernandez546
# Duplicated username svang
# Duplicated username sschlosser
# Duplicated username mlind
# Duplicated Email denisehall@roth-porter.com
# Duplicated username denise_hall166
# Duplicated username denise_hall166
# Duplicated username angelvega
# Duplicated username matthewmurphy
# Duplicated username matthewmurphy
# Duplicated username brittany07
# Duplicated username brittany07
# Duplicated username brittany07
# Duplicated username brittany07
# Duplicated Email gwendolyn22@example.net
# Duplicated username jeremiah.jackson976
# Duplicated username jeremiah.jackson976
# Duplicated username nicole.spencer445
# Duplicated username edgar.pieper485
# Duplicated username jasonserrano714
# Duplicated Email jamie_greer@knapp.com
# Duplicated username jburnett
# Duplicated username jburnett
# Duplicated username diane_vargas754
# Duplicated username david22
# Duplicated username stephengill141
# Duplicated username schristoffersen
# Duplicated username mosscaleb
# Duplicated username rachelnguyen130
# Duplicated username barozzifiorino
# Duplicated username brightgabriela
# Duplicated username paul_jennings75
# Duplicated username sara_love6
# Duplicated username jennifer_prince237
# Duplicated username danielbuck
# Duplicated username cpoirier
# Duplicated username rebekah_waters863
# Duplicated username paula_wilson262
# Duplicated username julia07
# Duplicated username michele91
# Duplicated username michele91
# Duplicated username bmcclain
# Duplicated username richardvaughan
# Duplicated username sharon.escobar896
# Duplicated username michaelavila694
# Duplicated username pascalstephanie
# Duplicated username david70
# Duplicated username emilywilkins
# Duplicated username bowmanjames
# Duplicated username mark.grant767
# Duplicated username zlopez
# Duplicated username zlopez
# Duplicated username samchristoffersen133
# Duplicated username samchristoffersen133
# Duplicated username cerigiovanna
# Duplicated username maxivaldés809
# Duplicated username adanielsen
# Duplicated username sarahsnow
# Duplicated username diane69
# Duplicated username heino97
# Duplicated username jérôme.gosselin161
# Duplicated username tinayoung446
# Duplicated username katiecolon130
# Duplicated username ppope
# Duplicated username sarahpeterson
# Duplicated username emmanuel25
# Duplicated username emmanuel25
# Duplicated Email garciaharold@example.com
# Duplicated username taylormcgee522
# Duplicated username dennis_romero96
# Duplicated username ferenc75
# Duplicated username joseph56
# Duplicated username pwilliams
# Duplicated username christianjohnson182
# Duplicated username jacksonrobin
# Duplicated username jacksonrobin
# Duplicated username craig_franklin844
# Duplicated username craig_franklin844
# Duplicated username jensenapril
# Duplicated username jensenapril
# Duplicated username curtrose
# Duplicated username curtrose
# Duplicated username robert_smith566
# Duplicated username kholland
# Duplicated username brian_mitchell695
# Duplicated username michael_rodriguez577
# Duplicated username gallartdorotea
# Duplicated username ashley.jimenez410
# Duplicated username lee.krause730
# Duplicated username emily.blair879
# Duplicated username mercedesmartorell262
# Duplicated username hallmaria
# Duplicated username martagiulietti
# Duplicated username yterry
# Duplicated username james76
# Duplicated username patrick_binner99
# Duplicated username monique12
# Duplicated username jockelroderich
# Duplicated username annette09
# Duplicated username sthompson
# Duplicated username dorothe.killer747
# Duplicated username jason28
# Duplicated username annettenelson71
# Duplicated username stevendavis148
# Duplicated username kevin_bradley938
# Duplicated username gottfried.barth472
# Duplicated username lonaklausen
# Duplicated username carlos.johnson224
# Duplicated username julie70
# Duplicated username stanleynovak
# Duplicated username timothée.albert597
# Duplicated username dostergaard
# Duplicated username armstrongrhonda
# Duplicated username alyssatorres
# Duplicated username jasminebaker
# Duplicated username jasminebaker
# Duplicated username kristie.carter221
# Duplicated username langtraci
# Duplicated username langtraci
# Duplicated username yanghannah
# Duplicated username karl_laursen256
# Duplicated username tammy.anderson499
# Duplicated username christina.duncan102
# Duplicated username poncio04
# Duplicated username kenneth93
# Duplicated username holtalisha
# Duplicated username lnorgaard
# Duplicated username gcain
# Duplicated username edoardo53
# Duplicated username lbach
# Duplicated username isabel75
# Duplicated username katrina92
# Duplicated username katrina92
# Duplicated username renethygesen
# Duplicated username renethygesen
# Duplicated username sandrajauregui
# Duplicated username kylewilliamson311
# Duplicated username kelly.sanders752
# Duplicated username kelly.sanders752
# Duplicated username noah.gregory446
# Duplicated username maurizio.baglioni156
# Duplicated username price
# Duplicated username louis_long158
# Duplicated username christie73
# Duplicated Email henry.frederiksen@iversen.org
# Duplicated username pirmin_ortmann319
# Duplicated username hamiltonkayla
# Duplicated username bettywatson265
# Duplicated username piersantivigorelli
# Duplicated username knud13
# Duplicated username niemeiererich
# Duplicated username celina95
# Duplicated username celina95
# Duplicated username ohartman
# Duplicated username matthew_hill686
# Duplicated username joshua_owens328
# Duplicated username ashley42
# Duplicated username dorte_mikkelsen937
# Duplicated username christinehill
# Duplicated username qpareto
# Duplicated username jeremíascoello902
# Duplicated username phillipsimmons
# Duplicated username phillipsimmons
# Duplicated username dortiz
# Duplicated username riley93
# Duplicated username cbryant
# Duplicated username shelby_burns412
# Duplicated username stephanie_foster505
# Duplicated username lazzaro.benigni120
# Duplicated username kimberly65
# Duplicated username knutkabus427
# Duplicated username dorothe.rudolph283
# Duplicated username thorntonheather
# Duplicated username bradleymoore541
# Duplicated username gerard05
# Duplicated username alexandra98
# Duplicated username erinpowers
# Duplicated username tanjasimonsen
# Duplicated username hilario.vergara915
# Duplicated username chadwoods489
# Duplicated username ocrawford
# Duplicated username ocrawford
# Duplicated username thomastrevor
# Duplicated username shannon.hunt311
# Duplicated username kristinemurray
# Duplicated username kristinemurray
# Duplicated username cwest
# Duplicated username henri.martin498
# Duplicated username csmith
# Duplicated username alfredo_iacobucci654
# Duplicated username nicolasforbes871
# Duplicated username amélie.thierry68
# Duplicated username ingried08
# Duplicated username ingried08
# Duplicated username ggordon
# Duplicated username belinda00
# Duplicated username belinda00
# Duplicated username belinda00
# Duplicated username john69
# Duplicated username lindsey_le269
# Duplicated username lindsey_le269
# Duplicated username barbarapowell712
# Duplicated username joseph_cole26
# Duplicated username donald90
# Duplicated username torresdavid
# Duplicated username michael78
# Duplicated username jared28
# Duplicated username javiermartinez881
# Duplicated username jcole
# Duplicated username jcole
# Duplicated username rico_pärtzelt10
# Duplicated username jason14
# Duplicated username daniel.hardy933
# Duplicated username angelinapavone
# Duplicated username tammyjenkins499
# Duplicated username gregoriogiulia
# Duplicated username danielrogers631
# Duplicated username wangchristopher
# Duplicated username ian.bowman266
# Duplicated username lcontarini
# Duplicated username zairafantoni
# Duplicated username kelly_harvey709
# Duplicated username jared_simmons691
# Duplicated username nicholas16
# Duplicated username derek_thompson4
# Duplicated username hayley_walker638
# Duplicated username gilmoredeborah
# Duplicated username amirhein973
# Duplicated username aimee43
# Duplicated username nina89
# Duplicated username smithlisa
# Duplicated username smithlisa
# Duplicated username mark_leblanc322
# Duplicated username ashlee12
# Duplicated username jason_thomas911
# Duplicated username maritalosada
# Duplicated username maritalosada
# Duplicated username christine65
# Duplicated username candiceburke
# Duplicated username candiceburke
# Duplicated username michael_mckinney761
# Duplicated username camachoantonio
# Duplicated username camachoantonio
# Duplicated username downswendy
# Duplicated username mendeannedore
# Duplicated username sabine.schwital348
# Duplicated username hbrown
# Duplicated username jeffrey32
# Duplicated username eddie_carpenter849
# Duplicated username johnsonjames
# Duplicated username tracyhall603
# Duplicated username tracyhall603
# Duplicated username davidandersen564
# Duplicated username karsten76
# Duplicated username galvezadalberto
# Duplicated username sarakristensen315
# Duplicated username wmccoy
# Duplicated username wmccoy
# Duplicated username williamwhite
# Duplicated username djohnson
# Duplicated username julie55
# Duplicated username saulienzo
# Duplicated username saulienzo
# Duplicated username michaelnguyen828
# Duplicated username thérèsebonnin144
# Duplicated username victorianewman
# Duplicated username ricky02
# Duplicated username ricky02
# Duplicated username evansdavid
# Duplicated username marcus.hoffman207
# Duplicated username marcus.hoffman207
# Duplicated username patrick.martin105
# Duplicated username audreyrenault366
# Duplicated username sean_romero32
# Duplicated username thomas.fuentes636
# Duplicated username wilsonlacey
# Duplicated username kristopher.miller913
# Duplicated username spiessmargitta
# Duplicated username spiessmargitta
# Duplicated Email lauren_smith@morris.org
# Duplicated username laurensmith713
# Duplicated username laurensmith713
# Duplicated username ymcdonald
# Duplicated username temistocle_fibonacci686
# Duplicated username tildethygesen279
# Duplicated username taylorfrye
# Duplicated username rufina_bernat472
# Duplicated username christopherthompson
# Duplicated username dsacristan
# Duplicated username jessica43
# Duplicated username marisa32
# Duplicated username robert_green93
# Duplicated username manuelbarth412
# Duplicated username karolina00
# Duplicated username charleswood
# Duplicated username jamesmartin
# Duplicated username jamesmartin
# Duplicated username meyersjames
# Duplicated username jenniferdaniel448
# Duplicated username martinezyolanda
# Duplicated username brose
# Duplicated username elizabethbowen
# Duplicated username ufriis
# Duplicated username hornichcatharina
# Duplicated username adriennegarza
# Duplicated username adriennegarza
# Duplicated username daniel_casanovas941
# Duplicated username smithrachel
# Duplicated username jaimemartinez
# Duplicated username jaimemartinez
# Duplicated username rachel.norton509
# Duplicated username martinelaurent879
# Duplicated username brookskathy
# Duplicated username julia67
# Duplicated username julia67
# Duplicated username anabel_carreño228
# Duplicated username ogrimes
# Duplicated username matthew.mendoza294
# Duplicated username kenneth04
# Duplicated username kenneth04
# Duplicated username kenneth04
# Duplicated username aloisioalfredo
# Duplicated username camille89
# Duplicated username brandi.brown642
# Duplicated username brandi.brown642
# Duplicated username osvald_toft173
# Duplicated username david_evans56
# Duplicated username david_evans56
# Duplicated username debora26
# Duplicated username debora26
# Duplicated username debora26
# Duplicated username marcelle_lemonnier491
# Duplicated username amanda_richards298
# Duplicated username randazzoloredana
# Duplicated username tristan71
# Duplicated username joanna_rodgers467
# Duplicated username nbass
# Duplicated username joseph.walters543
# Duplicated username charles95
# Duplicated Email soren59@example.com
# Duplicated username olekristoffersen
# Duplicated username olekristoffersen
# Duplicated username thomaslopez456
# Duplicated Email kerry_richards@smith-gomez.info
# Duplicated username kerry.richards219
# Duplicated username kerry.richards219
# Duplicated username veronique78
# Duplicated username nicholas_burke882
# Duplicated username nicholas_burke882
# Duplicated username nattamartino
# Duplicated Email carlotabermejo@grupo.com
# Duplicated username carlota_bermejo369
# Duplicated username babatogianpaolo
# Duplicated username babatogianpaolo
# Duplicated username felicitasheser369
# Duplicated username landofantoni766
# Duplicated username caseyharrell
# Duplicated username laura.taylor360
# Duplicated username scottgarrison588
# Duplicated username scott_nichols957
# Duplicated username emilevalentin
# Duplicated username emilevalentin
# Duplicated username emilevalentin
# Duplicated username odette_courtois757
# Duplicated username catherine.wolf395
# Duplicated username markøstergaard611
# Duplicated username robby23
# Duplicated username robby23
# Duplicated username tiffany_parks657
# Duplicated username jtaylor
# Duplicated username maricatroest
# Duplicated username fanny.patberg151
# Duplicated username descampsjoseph
# Duplicated username tannernoah
# Duplicated username michael68
# Duplicated username janicezuniga59
# Duplicated username janicezuniga59
# Duplicated username falloppioorlando
# Duplicated username deborahhawkins686
# Duplicated username filomena_navas970
# Duplicated username stinekristensen64
# Duplicated username paul.khan277
# Duplicated username peter.norton615
# Duplicated username lambertlisa
# Duplicated username brittany11
# Duplicated username alvarominguez
# Duplicated username johnsenjytte
# Duplicated username tony.cooper695
# Duplicated username justinfields157
# Duplicated username justinfields157
# Duplicated username lauren.white52
# Duplicated username friedostriebitz745
# Duplicated username jennifer.fleming554
# Duplicated username daniel61
# Duplicated username daniel61
# Duplicated username bjohnson
# Duplicated username sheppardjeremy
# Duplicated username sheppardjeremy
# Duplicated username élodie_millet395
# Duplicated username david_wheeler494
# Duplicated username gward
# Duplicated username ewest
# Duplicated username ewest
# Duplicated username pavelröhrdanz704
# Duplicated username juliereig
# Duplicated username juliereig
# Duplicated username debra15
# Duplicated username karl01
# Duplicated username romulo27
# Duplicated username april_young251
# Duplicated username amanda89
# Duplicated username amanda89
# Duplicated username holstnicolai
# Duplicated username wilmsenstefan
# Duplicated username zacharie98
# Duplicated username paul_hicks907
# Duplicated username florafo
# Duplicated username bennettbradley
# Duplicated username alfred_wheeler12
# Duplicated username teresacharles487
# Duplicated username jason_white120
# Duplicated username chad_brady262
# Duplicated username mauro77
# Duplicated username klee
# Duplicated username olfert_brandt848
# Duplicated username andrewsanchez80
# Duplicated username blochtheodor
# Duplicated username michael.moody227
# Duplicated username susan.schmidt5
# Duplicated username eneal
# Duplicated username eneal
# Duplicated username selma_toft171
# Duplicated username brianhall999
# Duplicated username sosaismael
# Duplicated username dustin.williams472
# Duplicated username erik.johann987
# Duplicated username marcia.clark538
# Duplicated username domenicosmirnoff978
# Duplicated username david02
# Duplicated username david02
# Duplicated username vmercado
# Duplicated username vmercado
# Duplicated username desiree_hines651
# Duplicated username azeglio23
# Duplicated username azeglio23
# Duplicated username mark_crosby199
# Duplicated username mark_crosby199
# Duplicated username karen.bell719
# Duplicated username mortenpaulsen494
# Duplicated username herminia28
# Duplicated username normanmatthew
# Duplicated username normanmatthew
# Duplicated username mohamed37
# Duplicated username ronaldboyd
# Duplicated username ronaldboyd
# Duplicated username georgejohn
# Duplicated username griselda.lloret353
# Duplicated username michaelbell272
# Duplicated username joshua_walsh47
# Duplicated username briana12
# Duplicated username kyliewise685
# Duplicated username miguelharrington29
# Duplicated username jacqueline01
# Duplicated username jacqueline01
# Duplicated username jimmyvance
# Duplicated username jimmyvance
# Duplicated username jonesnatalie
# Duplicated username paullacroix991
# Duplicated username paullacroix991
# Duplicated username nolson
# Duplicated username simonkjeldsen
# Duplicated username xrollins
# Duplicated username christian38
# Duplicated username rudolf09
# Duplicated username jenningsnicholas
# Duplicated username lindaowen145
# Duplicated username adelina_herranz91
# Duplicated username michaelwilson315
# Duplicated username dennis.gregersen35
# Duplicated username qrodriguez
# Duplicated username victoria.glass132
# Duplicated username charles18
# Duplicated username robert_brooks864
# Duplicated username timothy29
# Duplicated username timothy29
# Duplicated username vanessa_brock65
# Duplicated username taylorgreen931
# Duplicated username elizabeth_hill132
# Duplicated username victorsmith846
# Duplicated username victorsmith846
# Duplicated username jeffreyharmon656
# Duplicated username savannah49
# Duplicated username virgilio_cerquiglini170
# Duplicated username harpergarrett
# Duplicated username xlarsen
# Duplicated username blake_henderson994
# Duplicated username claire70
# Duplicated username patrick.hamilton792
# Duplicated username hwise
# Duplicated username xaviersmith
#         document                                          full_text  \
# 0     1221555001  Camille Collin, a student whose name is synony...
# 1     1221555002  Michael Stewart, a student identified by the I...
# 2     1221555003  Lisa Fernandez, a student identified by the ID...
# 3     1221555004  Joshua Vasquez, a student identified by the ID...
# 4     1221555005  Andrew Woodward, a student identified by the I...
# ...          ...                                                ...
# 5474  1221560475  As a budding historian, James Morris, whose In...
# 5475  1221560476  In the annals of academic achievement, Emily H...
# 5476  1221560477  In the realm of academia, every student embark...
# 5477  1221560478  In the tapestry of life, where threads of expe...
# 5478  1221560479  In the tapestry of life, personal experiences ...
#
#                                                  tokens  \
# 0     [Camille, Collin, ,, a, student, whose, name, ...
# 1     [Michael, Stewart, ,, a, student, identified, ...
# 2     [Lisa, Fernandez, ,, a, student, identified, b...
# 3     [Joshua, Vasquez, ,, a, student, identified, b...
# 4     [Andrew, Woodward, ,, a, student, identified, ...
# ...                                                 ...
# 5474  [As, a, budding, historian, ,, James, Morris, ...
# 5475  [In, the, annals, of, academic, achievement, ,...
# 5476  [In, the, realm, of, academia, ,, every, stude...
# 5477  [In, the, tapestry, of, life, ,, where, thread...
# 5478  [In, the, tapestry, of, life, ,, personal, exp...
#
#                                     trailing_whitespace  \
# 0     [True, False, True, True, True, True, True, Tr...
# 1     [True, False, True, True, True, True, True, Tr...
# 2     [True, False, True, True, True, True, True, Tr...
# 3     [True, False, True, True, True, True, True, Tr...
# 4     [True, False, True, True, True, True, True, Tr...
# ...                                                 ...
# 5474  [True, True, True, False, True, True, False, T...
# 5475  [True, True, True, True, True, False, True, Tr...
# 5476  [True, True, True, True, False, True, True, Tr...
# 5477  [True, True, True, True, False, True, True, Tr...
# 5478  [True, True, True, True, False, True, True, Tr...
#
#                                                  labels  \
# 0     [B-NAME_STUDENT, I-NAME_STUDENT, O, O, O, O, O...
# 1     [B-NAME_STUDENT, I-NAME_STUDENT, O, O, O, O, O...
# 2     [B-NAME_STUDENT, I-NAME_STUDENT, O, O, O, O, O...
# 3     [B-NAME_STUDENT, I-NAME_STUDENT, O, O, O, O, O...
# 4     [B-NAME_STUDENT, I-NAME_STUDENT, O, O, O, O, O...
# ...                                                 ...
# 5474  [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...
# 5475  [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...
# 5476  [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...
# 5477  [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...
# 5478  [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...
#
#                                               token_map     NAME_STUDENT  \
# 0     [{'B-NAME_STUDENT': ('Camille', 0)}, {'I-NAME_...   Camille Collin
# 1     [{'B-NAME_STUDENT': ('Michael', 0)}, {'I-NAME_...  Michael Stewart
# 2     [{'B-NAME_STUDENT': ('Lisa', 0)}, {'I-NAME_STU...   Lisa Fernandez
# 3     [{'B-NAME_STUDENT': ('Joshua', 0)}, {'I-NAME_S...   Joshua Vasquez
# 4     [{'B-NAME_STUDENT': ('Andrew', 0)}, {'I-NAME_S...  Andrew Woodward
# ...                                                 ...              ...
# 5474                                                 []
# 5475  [{'B-PHONE_NUM': ('+1', 253)}, {'I-PHONE_NUM':...
# 5476  [{'B-STREET_ADDRESS': ('167', 161)}, {'I-STREE...
# 5477  [{'B-PHONE_NUM': ('+1', 214)}, {'I-PHONE_NUM':...
# 5478                                                 []
#
#                                               EMAIL            USERNAME  \
# 0                          camille_collin@lebon.org           qfournier
# 1                         michael_stewart@green.com   michael_stewart95
# 2                             barbara42@example.org   lisa_fernandez687
# 3                joshua_vasquez@matthews-rogers.com    joshuavasquez599
# 4                          andrew_woodward@owen.biz  andrew_woodward465
# ...                                             ...                 ...
# 5474                    ['harrisdonna@hotmail.com']         ['derek90']
# 5475  ['suescott@hotmail.com', 'srose@hotmail.com']      ['geoffrey56']
# 5476                      ['jamesparker@yahoo.com']      ['lauraevans']
# 5477                      ['andrewklein@gmail.com']       ['bernard62']
# 5478                          ['rherman@gmail.com']                  []
#
#                           ID_NUM                 PHONE_NUM  \
# 0      374540118piRfBbnGbmACrWSv                0492938242
# 1      950714306wMZUIyJOxmcXfgrO              560-597-5351
# 2      731993941MIkyOoXoZzeKnzji             (209)347-1122
# 3      598658484zoGfhOYMyMHJRRWX              204.313.5256
# 4      156018640GGOOMjWIaubxppfU       +1-914-213-1456x208
# ...                          ...                       ...
# 5474  ['GB30ZHLC41715839903998']         ['(407)692-1342']
# 5475  ['GB30ZVTU13968666795951']       ['+1-543-965-0304']
# 5476                 ['416 YFG']         ['(747)388-6356']
# 5477               ['656443394']       ['+1-484-612-7646']
# 5478               ['001884899']  ['+1-810-639-5189x9133']
#
#                                            URL_PERSONAL  \
# 0                     https://linkedin.com/in/qfournier
# 1                  https://github.com/michael_stewart95
# 2               https://instagram.com/lisa_fernandez687
# 3                   https://github.com/joshuavasquez599
# 4            https://linkedin.com/in/andrew_woodward465
# ...                                                 ...
# 5474              ['https://instagram.com/amymorrison']
# 5475  ['https://linkedin.com/in/alejandrobarnes', 'h...
# 5476             ['https://linkedin.com/in/perezbryan']
# 5477            ['https://instagram.com/douglasmarcia']
# 5478              ['https://linkedin.com/in/william10']
#
#                                          STREET_ADDRESS
# 0          38, rue Nathalie Legrand 87438 VaillantBourg
# 1        711 Golden Overpass West Andreaville, OH 44115
# 2                       PSC 8684, Box 8339 APO AA 76482
# 3     98910 Cynthia Rest South Christopherville, AZ ...
# 4     45792 Tammy Centers Apt. 258 Davidmouth, TN 23414
# ...                                                 ...
# 5474  ['51593 Scott Forge Apt. 971\nNorth Brenda, KS...
# 5475  ['926 Branch Shores Apt. 411\nPort Lisa, CT 55...
# 5476         ['167 Dylan Cove\nLake Marissa, VI 40226']
# 5477  ['8815 Howard Village\nPrestonburgh, PA 49934'...
# 5478                                                 []
#
# [5479 rows x 13 columns]

# %%
# A function displays PII (like phone number) to help double-check the generated text
def verify_df(df):
    tmp = df
    tmp = tmp.reset_index(drop=True)
    for i in range(len(tmp)):
        row = tmp.iloc[i]
        full_text = row['full_text']
        tokens = row['tokens']
        token_map = row['token_map']
        address = row['STREET_ADDRESS']
        # Display full text and all
        print(f"=== Doc {i} ===\n"
              f"full_text = {full_text}\n"
              f"address = {address}")
        for t_dic in token_map:
            if 'B-STREET_ADDRESS' in t_dic.keys() or 'I-STREET_ADDRESS' in t_dic.keys():
                print(t_dic)
tmp = df[0:10]
verify_df(tmp)
# Out:
# === Doc 0 ===
# full_text = Camille Collin, a student whose name is synonymous with a vibrant spirit and unwavering determination, has left an indelible mark on the tapestry of her peers. With a captivating smile that illuminates the room and a mind that grasps complex concepts with ease, she has carved a unique path, leaving an imprint on all who encounter her.
#
# Collin's unwavering spirit is evident in her unwavering pursuit of knowledge. Her thirst for understanding knows no bounds, and her ability to delve deep into academic pursuits is unmatched. Her mind, sharp as a razor, effortlessly navigates intricate theories and concepts, transforming complex ideas into digestible and relatable insights.
#
# Beyond her academic prowess, Collin is known for her infectious energy and unwavering determination. She is a force of nature, capable of motivating others to reach their full potential. Her positive attitude is contagious, and her ability to inspire those around her is unmatched. Whether it's on the dance floor or in the classroom, Collin's presence brings joy and vitality to any situation.
#
# In addition to her academic achievements and her unwavering spirit, Collin is also a compassionate and caring individual. She is known for her unwavering empathy and her ability to understand and navigate the complexities of human emotions. Her kindness knows no bounds, and she is always willing to lend a helping hand to those in need.
#
# In conclusion, Camille Collin is an exceptional student whose unwavering spirit, boundless determination, and compassionate nature have touched countless lives. She is a beacon of inspiration for her peers, and her legacy extends far beyond the confines of the classroom. With her radiant smile and unwavering resolve, she continues to illuminate the world, leaving an indelible mark on all who encounter her.
# address = 38, rue Nathalie Legrand 87438 VaillantBourg
# === Doc 1 ===
# full_text = Michael Stewart, a student identified by the ID number 950714306wMZUIyJOxmcXfgrO, is a notable individual whose online presence and academic achievements exemplify the qualities of a well-rounded and ambitious individual. With a captivating username of "michael_stewart95," he has established a presence across various platforms, leaving an indelible mark on the digital landscape.
#
# Stewart's unwavering dedication to his studies is evident in his exceptional academic performance. His name, "Michael Stewart," is synonymous with excellence, as it has been etched in the annals of top-notch achievements. His ID number serves as a testament to his unique identity and unwavering determination.
#
# Beyond his academic pursuits, Stewart's online presence showcases his multifaceted personality. His username, "michael_stewart95," is a testament to his youthful vigor and unwavering spirit. His contributions to platforms such as GitHub under this username illustrate his technical prowess and collaborative spirit.
#
# Furthermore, Stewart's street address, 711 Golden Overpass West Andreaville, OH 44115, provides a glimpse into his personal realm, highlighting the connection between his physical and digital identities. It is a testament to the intricate relationship between the virtual and tangible worlds.
#
# In conclusion, Michael Stewart is an exceptional student and an inspiring individual whose accomplishments and online presence exemplify the potential for greatness. His unwavering dedication to academics, his exceptional online presence, and his unwavering spirit make him a role model for many. Through his achievements and contributions, Stewart has left an indelible mark on the digital landscape, leaving a legacy that inspires others to reach greater heights.
# address = 711 Golden Overpass West Andreaville, OH 44115
# {'B-STREET_ADDRESS': ('711', 178)}
# {'I-STREET_ADDRESS': ('Golden', 179)}
# {'I-STREET_ADDRESS': ('Overpass', 180)}
# {'I-STREET_ADDRESS': ('West', 181)}
# {'I-STREET_ADDRESS': ('Andreaville', 182)}
# {'I-STREET_ADDRESS': (',', 183)}
# {'I-STREET_ADDRESS': ('OH', 184)}
# {'I-STREET_ADDRESS': ('44115', 185)}
# === Doc 2 ===
# full_text = Lisa Fernandez, a student identified by the ID number 731993941MIkyOoXoZzeKnzji, is a notable individual whose presence on various platforms and association with a specific street address raise concerns about privacy and data protection.
#
# Ferandez's username, lisa_fernandez687, is used across multiple platforms, including Instagram, where she has a personal profile. Her email address, barbara42@example.org, is publicly available on her Instagram profile, along with her phone number, (209)347-1122. These personal details provide a direct connection to Fernandez, making it easy for anyone to reach her.
#
# Furthermore, her street address, PSC 8684, Box 8339 APO AA 76482, is associated with her name and ID number. This information is sensitive and should not be publicly shared. It is crucial to protect individuals' privacy and ensure that their personal data is not accessible to unauthorized individuals.
#
# In conclusion, the presence of Lisa Fernandez's personal information on various platforms and the association of her street address with her ID number raise concerns about privacy and data protection. It is imperative to safeguard individuals' rights and ensure that their personal information remains confidential and secure.
# address = PSC 8684, Box 8339 APO AA 76482
# {'B-STREET_ADDRESS': ('PSC', 110)}
# {'I-STREET_ADDRESS': ('8684', 111)}
# {'I-STREET_ADDRESS': (',', 112)}
# {'I-STREET_ADDRESS': ('Box', 113)}
# {'I-STREET_ADDRESS': ('8339', 114)}
# {'I-STREET_ADDRESS': ('APO', 115)}
# {'I-STREET_ADDRESS': ('AA', 116)}
# {'I-STREET_ADDRESS': ('76482', 117)}
# === Doc 3 ===
# full_text = Joshua Vasquez, a student identified by the ID number 598658484zoGfhOYMyMHJRRWX, is a notable individual whose accomplishments and contributions merit recognition. With a vibrant online presence and a strong academic standing, Vasquez embodies the spirit of a well-rounded individual.
#
# Vasquez's online presence is evident through his active username, joshuavasquez599, on various platforms. He has a captivating profile on GitHub, showcasing his coding abilities and passion for technology. His contributions to open-source projects demonstrate his willingness to share his knowledge and collaborate with others.
#
# Academically, Vasquez has consistently impressed instructors and peers alike. His exceptional writing skills and insightful analytical abilities have earned him recognition in various academic pursuits. His ability to articulate complex ideas clearly and concisely is a testament to his intellectual prowess.
#
# Beyond the academic realm, Vasquez is known for his exceptional communication and interpersonal skills. He has a friendly and approachable demeanor, making it easy for others to connect with him. His ability to build and maintain strong relationships is evident in his wide circle of friends and supporters.
#
# In conclusion, Joshua Vasquez is an exceptional student and an inspiring individual whose accomplishments and contributions extend far beyond the confines of academia. With his unwavering determination, boundless creativity, and unwavering spirit, he serves as a role model for his peers and a testament to the transformative power of education and personal growth.
# address = 98910 Cynthia Rest South Christopherville, AZ 79865
# === Doc 4 ===
# full_text = Andrew Woodward, a student identified by the ID number 156018640GGOOMjWIaubxppfU, is a notable individual whose online presence and academic achievements exemplify the qualities of a well-rounded and ambitious individual. With a captivating online persona and a strong academic record, Woodward has established himself as a prominent figure within his community.
#
# Woodward's online presence is characterized by his engaging username, "andrew_woodward465," which he utilizes across various platforms, including LinkedIn and other social media outlets. Through his online interactions, Woodward has cultivated a network of connections, showcasing his intellect and thought-provoking perspectives. His contributions to online forums and discussions demonstrate his ability to engage in meaningful conversations and contribute valuable insights.
#
# Academically, Woodward has consistently impressed with his exceptional academic achievements. His ID number serves as a testament to his accomplishments, signifying his standing as a highly motivated and capable student. With a strong understanding of various subjects, Woodward has consistently excelled in his studies, earning recognition for his exceptional performance.
#
# Beyond his academic pursuits, Woodward's interests extend beyond the confines of academia. He has a passion for music, technology, and travel, which he often incorporates into his online interactions and daily routines. His ability to balance his academic commitments with his personal pursuits is a testament to his resilience and determination.
#
# In conclusion, Andrew Woodward is an exceptional student and an inspiring individual whose online presence and academic achievements exemplify the qualities of a well-rounded and ambitious individual. With his engaging online persona, strong academic record, and unwavering determination, Woodward has left a positive impact on his community and continues to inspire others to pursue their passions and aspirations.
# address = 45792 Tammy Centers Apt. 258 Davidmouth, TN 23414
# === Doc 5 ===
# full_text = Albert Soto, a student identified by the ID number 155994520JqMnWTzCCpebJLaT, is a notable individual whose online presence and academic achievements exemplify the qualities of a well-rounded and ambitious individual.
#
# Soto's online presence is characterized by his active username, tverdugo, which he utilizes across various platforms. Through this username, he has established a reputation for himself as a content creator and active participant in online communities. His YouTube channel, accessible at the URL, tverdugo, showcases his creativity and passion for various topics.
#
# Academically, Soto has demonstrated exceptional prowess. His ID number serves as a testament to his accomplishments, highlighting his standing as a student of distinction. His street address, Cañada de Ignacia Palomar 592 Piso 6  Álava, 39966, provides a glimpse into his physical presence, while his phone number, +34717150842, allows for direct communication.
#
# In conclusion, Albert Soto is a remarkable student whose online presence and academic achievements illustrate his intelligence, creativity, and ambition. His story serves as an inspiration to others, demonstrating the potential for individuals to excel in both their personal and academic pursuits.
# address = Cañada de Ignacia Palomar 592 Piso 6  Álava, 39966
# {'B-STREET_ADDRESS': ('Cañada', 130)}
# {'I-STREET_ADDRESS': ('de', 131)}
# {'I-STREET_ADDRESS': ('Ignacia', 132)}
# {'I-STREET_ADDRESS': ('Palomar', 133)}
# {'I-STREET_ADDRESS': ('592', 134)}
# {'I-STREET_ADDRESS': ('Piso', 135)}
# {'I-STREET_ADDRESS': ('6', 136)}
# === Doc 6 ===
# full_text = James Cook, a student identified by the ID number 58083612epQniKpZmgwAURdU, is a notable individual whose presence on various platforms and association with a specific street address raise concerns about privacy and data protection.
#
# Cook's online presence is evident through his username, jeffreywest, on platforms such as LinkedIn. His email address, james_cook@hutchinson.biz, is also publicly available. These identifiers enable individuals to easily locate and connect with Cook.
#
# Furthermore, Cook's street address, 0638 Mary Curve Apt. 665 East Alexistown, GU 89074, is a sensitive personal information that should not be shared publicly. This information could lead to various security risks, such as identity theft or targeted harassment.
#
# The combination of Cook's identifiable information, including his name, address, and phone number, raises concerns about privacy and data protection. It is crucial to safeguard sensitive personal information and ensure that it is not shared or misused without consent.
#
# In conclusion, the presence of James Cook's identifiable information on various platforms and the association of his street address with his name raise serious concerns about privacy and data protection. It is imperative to protect individuals' rights to privacy and ensure that their personal information is handled responsibly.
# address = 0638 Mary Curve Apt. 665 East Alexistown, GU 89074
# {'B-STREET_ADDRESS': ('0638', 86)}
# {'I-STREET_ADDRESS': ('Mary', 87)}
# {'I-STREET_ADDRESS': ('Curve', 88)}
# {'I-STREET_ADDRESS': ('Apt', 89)}
# {'I-STREET_ADDRESS': ('.', 90)}
# {'I-STREET_ADDRESS': ('665', 91)}
# {'I-STREET_ADDRESS': ('East', 92)}
# {'I-STREET_ADDRESS': ('Alexistown', 93)}
# {'I-STREET_ADDRESS': (',', 94)}
# {'I-STREET_ADDRESS': ('GU', 95)}
# {'I-STREET_ADDRESS': ('89074', 96)}
# === Doc 7 ===
# full_text = In the realm of digital connectivity and personal information, Allison Davis emerges as a captivating figure whose online presence and associated data illuminate the interconnected web of modern society. With a unique blend of anonymity and accessibility, she has carved a niche for herself, leaving an indelible mark on the virtual landscape.
#
# Davis's pseudonym, "franklinjames," underscores her enigmatic nature, hinting at the multifaceted persona she has cultivated. Her email address, allison.davis@ramirez-good.com, serves as a gateway to her virtual realm, where she engages with others under her chosen alias. Through her username, franklinjames, she navigates various platforms, leaving a trail of digital breadcrumbs that reveal her interests and aspirations.
#
# Beyond the realm of the digital, Davis's identity is intertwined with her physical address, 485 Mays Vista Port Karafort, VT 84930, and phone number, 661.204.7142x8512. These personal details provide a glimpse into her private world, albeit limited by the boundaries of privacy. Her URL_PERSONAL, youtube.com/c/franklinjames, serves as a testament to her presence on YouTube, where she has cultivated a virtual presence under her pseudonym.
#
# In conclusion, Allison Davis is a multifaceted individual whose digital footprint and personal information illuminate the interconnected tapestry of modern society. While her anonymity affords her a sense of privacy, her accessibility through various platforms and data points allows for a glimpse into her virtual and physical realms. Through her pseudonym, email address, and online presence, Davis has created a unique identity that transcends the boundaries of anonymity and accessibility.
# address = 485 Mays Vista Port Karafort, VT 84930
# {'B-STREET_ADDRESS': ('485', 147)}
# {'I-STREET_ADDRESS': ('Mays', 148)}
# {'I-STREET_ADDRESS': ('Vista', 149)}
# {'I-STREET_ADDRESS': ('Port', 150)}
# {'I-STREET_ADDRESS': ('Karafort', 151)}
# {'I-STREET_ADDRESS': (',', 152)}
# {'I-STREET_ADDRESS': ('VT', 153)}
# {'I-STREET_ADDRESS': ('84930', 154)}
# === Doc 8 ===
# full_text = In the realm of digital connectivity and personal information, Samira Mies emerges as a captivating figure whose online presence and intimate details illuminate the interconnected web of our modern era. With a captivating array of values associated with her name, email, username, ID number, phone number, and street address, she embodies the complexities of privacy and the delicate balance between personal exposure and safeguarding sensitive data.
#
# Mies's username, "samira_mies195," serves as a testament to her vibrant personality and unwavering presence on various platforms. Her email address, "samiramies@haenel.org," provides a glimpse into her innermost world, revealing her name and the domain name of her chosen email provider. While her ID number and phone number offer a means of identification and communication, they also serve as vulnerabilities that necessitate caution and privacy measures.
#
# Beyond the realm of digital identifiers, Mies's street address, "Georgios-Sauer-Ring 6 41730 Eisenberg," divulges her physical location, making her susceptible to potential harm or intrusion. The country of her residence, "de_DE," further illuminates her geographical identity. It is imperative to recognize the gravity of sharing such intimate information, as it can have profound consequences for one's safety, security, and privacy.
#
# Mies's story underscores the delicate interplay between personal expression and the safeguarding of sensitive data. While her online presence and shared information provide a window into her life, it is crucial to recognize the potential risks associated with divulging such intimate details. The balance between privacy and the desire for connection is a delicate one, and it requires careful consideration of the potential consequences.
#
# In conclusion, Samira Mies's journey through the interconnected digital landscape illuminates the complexities of personal information and privacy. Her story serves as a cautionary tale about the importance of safeguarding sensitive data while maintaining a vibrant online presence. By understanding the potential vulnerabilities associated with sharing intimate information, we can empower ourselves to make informed decisions about how much we choose to reveal about ourselves.
# address = Georgios-Sauer-Ring 6 41730 Eisenberg
# === Doc 9 ===
# full_text = Ritt Lauritsen is a student whose information has been provided. He has a unique ID number, phone number, and email address. His username is also unique. He has a personal URL that can be used to identify him on social media. Additionally, he has a street address that can be partially identified.
#
# Lauritsen is a student who has a lot of personal information available online. This information could be used for a variety of purposes, including identity theft or stalking. It is important to be aware of the risks associated with sharing personal information online.
#
# Lauritsen's story is a cautionary tale about the importance of privacy. It is important to be mindful of the information that is shared online, as it can have a significant impact on one's life.
# address = Kasematvej 3 2961 Hornslet
